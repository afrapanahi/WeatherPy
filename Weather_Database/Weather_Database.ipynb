# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low = -90, high = 90, size=2000)
lngs = np.random.uniform(low = -90, high = 90, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = []

coordinates = [x for x in lat_lngs]
len(coordinates)
# Out:
# 2000

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities=[]

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 739

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "https://api.openweathermap.org/data/2.5/weather?&units=imperial&appid=" + weather_api_key
city_url = url + "&q=" + cities[0].replace(" ","+")
city_weather = requests.get(city_url).json()
city_weather
# Out:
# {'coord': {'lon': -85.9175, 'lat': 12.9256},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02n'}],
#  'base': 'stations',
#  'main': {'temp': 63.93,
#   'feels_like': 64.58,
#   'temp_min': 63.93,
#   'temp_max': 63.93,
#   'pressure': 1015,
#   'humidity': 97,
#   'sea_level': 1015,
#   'grnd_level': 930},
#  'visibility': 10000,
#  'wind': {'speed': 3.78, 'deg': 22, 'gust': 3.89},
#  'clouds': {'all': 24},
#  'dt': 1672471945,
#  'sys': {'country': 'NI', 'sunrise': 1672488316, 'sunset': 1672529268},
#  'timezone': -21600,
#  'id': 3617708,
#  'name': 'Matagalpa',
#  'cod': 200}

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_des = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          #"Date": city_date,
                          "Current Description": city_des})       
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | matagalpa
# Processing Record 2 of Set 1 | hithadhoo
# Processing Record 3 of Set 1 | ponta delgada
# Processing Record 4 of Set 1 | manavgat
# Processing Record 5 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 1 | yellamanchili
# City not found. Skipping...
# Processing Record 7 of Set 1 | vila franca do campo
# Processing Record 8 of Set 1 | saint george
# Processing Record 9 of Set 1 | faya
# Processing Record 10 of Set 1 | saint-philippe
# Processing Record 11 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 1 | arraial do cabo
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | potgietersrus
# City not found. Skipping...
# Processing Record 16 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 1 | narsaq
# Processing Record 18 of Set 1 | elblag
# Processing Record 19 of Set 1 | bur gabo
# City not found. Skipping...
# Processing Record 20 of Set 1 | pisco
# Processing Record 21 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 1 | port alfred
# Processing Record 23 of Set 1 | mahebourg
# Processing Record 24 of Set 1 | cape town
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | touba
# Processing Record 27 of Set 1 | marystown
# Processing Record 28 of Set 1 | castro
# Processing Record 29 of Set 1 | kiruna
# Processing Record 30 of Set 1 | mar del plata
# Processing Record 31 of Set 1 | balkanabat
# Processing Record 32 of Set 1 | abu zabad
# Processing Record 33 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 34 of Set 1 | kuldiga
# Processing Record 35 of Set 1 | port loko
# Processing Record 36 of Set 1 | methoni
# Processing Record 37 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 1 | bani
# Processing Record 39 of Set 1 | bredasdorp
# Processing Record 40 of Set 1 | ribeira grande
# Processing Record 41 of Set 1 | upernavik
# Processing Record 42 of Set 1 | souillac
# Processing Record 43 of Set 1 | alta floresta
# Processing Record 44 of Set 1 | saldanha
# Processing Record 45 of Set 1 | bondo
# Processing Record 46 of Set 1 | beira
# Processing Record 47 of Set 1 | abu samrah
# Processing Record 48 of Set 1 | comodoro rivadavia
# Processing Record 49 of Set 1 | tulsipur
# Processing Record 50 of Set 1 | tasiilaq
# Processing Record 1 of Set 2 | lagoa
# Processing Record 2 of Set 2 | lafia
# Processing Record 3 of Set 2 | formosa
# Processing Record 4 of Set 2 | abapo
# Processing Record 5 of Set 2 | chuy
# Processing Record 6 of Set 2 | port hawkesbury
# Processing Record 7 of Set 2 | sechura
# Processing Record 8 of Set 2 | port elizabeth
# Processing Record 9 of Set 2 | troitsko-pechorsk
# Processing Record 10 of Set 2 | makrana
# Processing Record 11 of Set 2 | buchanan
# Processing Record 12 of Set 2 | ndioum
# Processing Record 13 of Set 2 | jamestown
# Processing Record 14 of Set 2 | warrington
# Processing Record 15 of Set 2 | sarkand
# Processing Record 16 of Set 2 | dikson
# Processing Record 17 of Set 2 | lugovoy
# Processing Record 18 of Set 2 | karamay
# City not found. Skipping...
# Processing Record 19 of Set 2 | bambous virieux
# Processing Record 20 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 2 | ilulissat
# Processing Record 22 of Set 2 | honningsvag
# Processing Record 23 of Set 2 | barranca
# Processing Record 24 of Set 2 | moussoro
# Processing Record 25 of Set 2 | sliven
# Processing Record 26 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 2 | ler
# Processing Record 28 of Set 2 | atar
# Processing Record 29 of Set 2 | albion
# Processing Record 30 of Set 2 | bull savanna
# Processing Record 31 of Set 2 | cabedelo
# Processing Record 32 of Set 2 | yar-sale
# Processing Record 33 of Set 2 | touros
# Processing Record 34 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 2 | pangnirtung
# Processing Record 36 of Set 2 | la macarena
# Processing Record 37 of Set 2 | mporokoso
# Processing Record 38 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 2 | vestmannaeyjar
# Processing Record 40 of Set 2 | ancud
# Processing Record 41 of Set 2 | kinsale
# Processing Record 42 of Set 2 | nanortalik
# Processing Record 43 of Set 2 | luderitz
# Processing Record 44 of Set 2 | kuryk
# Processing Record 45 of Set 2 | grindavik
# Processing Record 46 of Set 2 | beloha
# Processing Record 47 of Set 2 | bogorodskoye
# Processing Record 48 of Set 2 | xai-xai
# Processing Record 49 of Set 2 | port-gentil
# Processing Record 50 of Set 2 | san alberto
# Processing Record 1 of Set 3 | urdzhar
# City not found. Skipping...
# Processing Record 2 of Set 3 | clyde river
# Processing Record 3 of Set 3 | east london
# Processing Record 4 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 5 of Set 3 | cidreira
# Processing Record 6 of Set 3 | tarnobrzeg
# Processing Record 7 of Set 3 | olafsvik
# Processing Record 8 of Set 3 | walvis bay
# Processing Record 9 of Set 3 | ponta do sol
# Processing Record 10 of Set 3 | rawson
# Processing Record 11 of Set 3 | odweyne
# Processing Record 12 of Set 3 | kamenka
# Processing Record 13 of Set 3 | lebu
# Processing Record 14 of Set 3 | kruisfontein
# Processing Record 15 of Set 3 | achisay
# City not found. Skipping...
# Processing Record 16 of Set 3 | valparaiso
# Processing Record 17 of Set 3 | maceio
# Processing Record 18 of Set 3 | razole
# Processing Record 19 of Set 3 | mao
# Processing Record 20 of Set 3 | de aar
# Processing Record 21 of Set 3 | paamiut
# Processing Record 22 of Set 3 | prado
# Processing Record 23 of Set 3 | punta ocote
# Processing Record 24 of Set 3 | georgetown
# Processing Record 25 of Set 3 | mecca
# Processing Record 26 of Set 3 | misratah
# Processing Record 27 of Set 3 | saint-augustin
# Processing Record 28 of Set 3 | codrington
# Processing Record 29 of Set 3 | muana
# Processing Record 30 of Set 3 | salinas
# Processing Record 31 of Set 3 | mehamn
# Processing Record 32 of Set 3 | pitimbu
# Processing Record 33 of Set 3 | volga
# Processing Record 34 of Set 3 | kutum
# Processing Record 35 of Set 3 | torbay
# Processing Record 36 of Set 3 | chardara
# Processing Record 37 of Set 3 | dingle
# Processing Record 38 of Set 3 | marathokambos
# City not found. Skipping...
# Processing Record 39 of Set 3 | mushie
# Processing Record 40 of Set 3 | iqaluit
# Processing Record 41 of Set 3 | la maddalena
# Processing Record 42 of Set 3 | batsfjord
# Processing Record 43 of Set 3 | mongu
# Processing Record 44 of Set 3 | mabaruma
# Processing Record 45 of Set 3 | ciudad bolivar
# Processing Record 46 of Set 3 | qaqortoq
# Processing Record 47 of Set 3 | kaele
# Processing Record 48 of Set 3 | savannah bight
# Processing Record 49 of Set 3 | tobermory
# Processing Record 50 of Set 3 | wattegama
# Processing Record 1 of Set 4 | constantine
# Processing Record 2 of Set 4 | saint-pierre
# Processing Record 3 of Set 4 | takoradi
# Processing Record 4 of Set 4 | san andres
# Processing Record 5 of Set 4 | havoysund
# Processing Record 6 of Set 4 | raudeberg
# Processing Record 7 of Set 4 | saint-leu
# Processing Record 8 of Set 4 | conneaut
# Processing Record 9 of Set 4 | busselton
# Processing Record 10 of Set 4 | oksfjord
# Processing Record 11 of Set 4 | olavarria
# Processing Record 12 of Set 4 | sao joao da barra
# Processing Record 13 of Set 4 | mariental
# Processing Record 14 of Set 4 | narasannapeta
# Processing Record 15 of Set 4 | camapua
# Processing Record 16 of Set 4 | kashi
# Processing Record 17 of Set 4 | zakharovo
# Processing Record 18 of Set 4 | somerset
# Processing Record 19 of Set 4 | duns
# Processing Record 20 of Set 4 | gewane
# Processing Record 21 of Set 4 | velsk
# Processing Record 22 of Set 4 | rabo de peixe
# Processing Record 23 of Set 4 | hofn
# Processing Record 24 of Set 4 | novosheshminsk
# Processing Record 25 of Set 4 | bayan
# Processing Record 26 of Set 4 | mahanoro
# Processing Record 27 of Set 4 | aleysk
# Processing Record 28 of Set 4 | vicuna
# Processing Record 29 of Set 4 | asyut
# Processing Record 30 of Set 4 | ungheni
# Processing Record 31 of Set 4 | adrar
# Processing Record 32 of Set 4 | bandipur
# Processing Record 33 of Set 4 | husavik
# Processing Record 34 of Set 4 | ureki
# Processing Record 35 of Set 4 | emba
# Processing Record 36 of Set 4 | cockburn town
# Processing Record 37 of Set 4 | qaanaaq
# Processing Record 38 of Set 4 | taoudenni
# Processing Record 39 of Set 4 | salalah
# Processing Record 40 of Set 4 | itaituba
# Processing Record 41 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 4 | boffa
# Processing Record 43 of Set 4 | nyrob
# Processing Record 44 of Set 4 | tortoli
# Processing Record 45 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 46 of Set 4 | dalbandin
# Processing Record 47 of Set 4 | igrim
# Processing Record 48 of Set 4 | oranjemund
# Processing Record 49 of Set 4 | el alto
# Processing Record 50 of Set 4 | doha
# Processing Record 1 of Set 5 | chapais
# Processing Record 2 of Set 5 | nioro
# Processing Record 3 of Set 5 | bonavista
# Processing Record 4 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 5 | odienne
# Processing Record 6 of Set 5 | tubuala
# Processing Record 7 of Set 5 | koscian
# Processing Record 8 of Set 5 | calabozo
# Processing Record 9 of Set 5 | jacksonville beach
# Processing Record 10 of Set 5 | lancaster
# Processing Record 11 of Set 5 | victoria
# Processing Record 12 of Set 5 | sovetskiy
# Processing Record 13 of Set 5 | lardos
# Processing Record 14 of Set 5 | camacha
# Processing Record 15 of Set 5 | sorland
# Processing Record 16 of Set 5 | escanaba
# Processing Record 17 of Set 5 | morro agudo
# Processing Record 18 of Set 5 | kortkeros
# Processing Record 19 of Set 5 | klaksvik
# Processing Record 20 of Set 5 | najran
# Processing Record 21 of Set 5 | igra
# Processing Record 22 of Set 5 | longyearbyen
# Processing Record 23 of Set 5 | port blair
# Processing Record 24 of Set 5 | tawnat
# City not found. Skipping...
# Processing Record 25 of Set 5 | porto novo
# Processing Record 26 of Set 5 | pirgos
# Processing Record 27 of Set 5 | mpulungu
# Processing Record 28 of Set 5 | oriximina
# Processing Record 29 of Set 5 | barao de melgaco
# Processing Record 30 of Set 5 | sebeta
# Processing Record 31 of Set 5 | bam
# Processing Record 32 of Set 5 | manta
# Processing Record 33 of Set 5 | taltal
# Processing Record 34 of Set 5 | magadi
# Processing Record 35 of Set 5 | angoche
# Processing Record 36 of Set 5 | matameye
# City not found. Skipping...
# Processing Record 37 of Set 5 | kautokeino
# Processing Record 38 of Set 5 | taywarah
# Processing Record 39 of Set 5 | san cristobal
# Processing Record 40 of Set 5 | benguela
# Processing Record 41 of Set 5 | san clemente
# Processing Record 42 of Set 5 | harlingen
# Processing Record 43 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 44 of Set 5 | sao raimundo nonato
# Processing Record 45 of Set 5 | santa maria
# Processing Record 46 of Set 5 | bilma
# Processing Record 47 of Set 5 | bengkulu
# Processing Record 48 of Set 5 | bondoukou
# Processing Record 49 of Set 5 | yertsevo
# Processing Record 50 of Set 5 | ust-tsilma
# Processing Record 1 of Set 6 | mendoza
# Processing Record 2 of Set 6 | requena
# Processing Record 3 of Set 6 | verviers
# Processing Record 4 of Set 6 | harper
# Processing Record 5 of Set 6 | nova bystrice
# Processing Record 6 of Set 6 | krasnovishersk
# Processing Record 7 of Set 6 | pavlodar
# Processing Record 8 of Set 6 | matara
# Processing Record 9 of Set 6 | garissa
# Processing Record 10 of Set 6 | mogadishu
# Processing Record 11 of Set 6 | ziyamet
# City not found. Skipping...
# Processing Record 12 of Set 6 | urengoy
# Processing Record 13 of Set 6 | sao marcos
# Processing Record 14 of Set 6 | caravelas
# Processing Record 15 of Set 6 | los llanos de aridane
# Processing Record 16 of Set 6 | morros
# Processing Record 17 of Set 6 | pozega
# Processing Record 18 of Set 6 | aripuana
# Processing Record 19 of Set 6 | gleisdorf
# Processing Record 20 of Set 6 | hamilton
# Processing Record 21 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 22 of Set 6 | kozhva
# Processing Record 23 of Set 6 | sesheke
# Processing Record 24 of Set 6 | berlevag
# Processing Record 25 of Set 6 | chimbote
# Processing Record 26 of Set 6 | kalmunai
# Processing Record 27 of Set 6 | olinda
# Processing Record 28 of Set 6 | sao jose da coroa grande
# Processing Record 29 of Set 6 | meulaboh
# Processing Record 30 of Set 6 | goderich
# Processing Record 31 of Set 6 | shumikha
# Processing Record 32 of Set 6 | maldonado
# Processing Record 33 of Set 6 | praia
# Processing Record 34 of Set 6 | corrente
# Processing Record 35 of Set 6 | bolshiye klyuchishchi
# City not found. Skipping...
# Processing Record 36 of Set 6 | malkapur
# Processing Record 37 of Set 6 | bereda
# Processing Record 38 of Set 6 | villarrica
# Processing Record 39 of Set 6 | diego de almagro
# Processing Record 40 of Set 6 | soyo
# Processing Record 41 of Set 6 | deori khas
# Processing Record 42 of Set 6 | morondava
# Processing Record 43 of Set 6 | kolda
# Processing Record 44 of Set 6 | kemijarvi
# Processing Record 45 of Set 6 | haselunne
# Processing Record 46 of Set 6 | bukama
# Processing Record 47 of Set 6 | bandarbeyla
# Processing Record 48 of Set 6 | kez
# Processing Record 49 of Set 6 | carauari
# Processing Record 50 of Set 6 | boca do acre
# Processing Record 1 of Set 7 | santa cruz
# Processing Record 2 of Set 7 | mana
# Processing Record 3 of Set 7 | sao filipe
# Processing Record 4 of Set 7 | hualmay
# Processing Record 5 of Set 7 | tabasalu
# Processing Record 6 of Set 7 | sabzevar
# Processing Record 7 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 8 of Set 7 | praia da vitoria
# Processing Record 9 of Set 7 | ostrovnoy
# Processing Record 10 of Set 7 | itarema
# Processing Record 11 of Set 7 | masvingo
# Processing Record 12 of Set 7 | zhanakorgan
# Processing Record 13 of Set 7 | adeje
# Processing Record 14 of Set 7 | zhanatas
# City not found. Skipping...
# Processing Record 15 of Set 7 | bolshiye uki
# City not found. Skipping...
# Processing Record 16 of Set 7 | lima
# Processing Record 17 of Set 7 | diofior
# Processing Record 18 of Set 7 | middleton
# Processing Record 19 of Set 7 | denia
# Processing Record 20 of Set 7 | benghazi
# Processing Record 21 of Set 7 | general roca
# Processing Record 22 of Set 7 | veraval
# Processing Record 23 of Set 7 | tessalit
# Processing Record 24 of Set 7 | bertoua
# Processing Record 25 of Set 7 | kharan
# Processing Record 26 of Set 7 | antofagasta
# Processing Record 27 of Set 7 | surab
# Processing Record 28 of Set 7 | sudbury
# Processing Record 29 of Set 7 | salzburg
# Processing Record 30 of Set 7 | maniitsoq
# Processing Record 31 of Set 7 | kang
# Processing Record 32 of Set 7 | koyilandi
# City not found. Skipping...
# Processing Record 33 of Set 7 | talara
# Processing Record 34 of Set 7 | cape canaveral
# Processing Record 35 of Set 7 | laguna
# Processing Record 36 of Set 7 | adwa
# Processing Record 37 of Set 7 | salta
# Processing Record 38 of Set 7 | esna
# Processing Record 39 of Set 7 | gautier
# Processing Record 40 of Set 7 | emborion
# Processing Record 41 of Set 7 | carballo
# Processing Record 42 of Set 7 | ongandjera
# Processing Record 43 of Set 7 | pachino
# Processing Record 44 of Set 7 | mocambique
# City not found. Skipping...
# Processing Record 45 of Set 7 | barcelos
# Processing Record 46 of Set 7 | sayyan
# Processing Record 47 of Set 7 | necochea
# Processing Record 48 of Set 7 | shadrinsk
# Processing Record 49 of Set 7 | radhanpur
# Processing Record 50 of Set 7 | dujuma
# City not found. Skipping...
# Processing Record 1 of Set 8 | izyum
# Processing Record 2 of Set 8 | plettenberg bay
# Processing Record 3 of Set 8 | mercedes
# Processing Record 4 of Set 8 | limoges
# Processing Record 5 of Set 8 | marquette
# Processing Record 6 of Set 8 | tocopilla
# Processing Record 7 of Set 8 | namibe
# Processing Record 8 of Set 8 | natal
# Processing Record 9 of Set 8 | gari
# Processing Record 10 of Set 8 | kamnik
# Processing Record 11 of Set 8 | mananara
# Processing Record 12 of Set 8 | hwange
# Processing Record 13 of Set 8 | coracora
# Processing Record 14 of Set 8 | borama
# City not found. Skipping...
# Processing Record 15 of Set 8 | filingue
# Processing Record 16 of Set 8 | capela
# Processing Record 17 of Set 8 | kalabo
# Processing Record 18 of Set 8 | quelimane
# Processing Record 19 of Set 8 | vriezenveen
# Processing Record 20 of Set 8 | bahawalpur
# Processing Record 21 of Set 8 | maragogi
# Processing Record 22 of Set 8 | hammerfest
# Processing Record 23 of Set 8 | gat
# Processing Record 24 of Set 8 | xuddur
# Processing Record 25 of Set 8 | contamana
# Processing Record 26 of Set 8 | port-cartier
# Processing Record 27 of Set 8 | almenevo
# City not found. Skipping...
# Processing Record 28 of Set 8 | itagiba
# Processing Record 29 of Set 8 | muromtsevo
# Processing Record 30 of Set 8 | karasjok
# Processing Record 31 of Set 8 | malia
# Processing Record 32 of Set 8 | eyl
# Processing Record 33 of Set 8 | effingham
# Processing Record 34 of Set 8 | tumaco
# Processing Record 35 of Set 8 | koungou
# Processing Record 36 of Set 8 | muisne
# Processing Record 37 of Set 8 | himora
# City not found. Skipping...
# Processing Record 38 of Set 8 | surt
# Processing Record 39 of Set 8 | kavaratti
# Processing Record 40 of Set 8 | hambantota
# Processing Record 41 of Set 8 | pimentel
# Processing Record 42 of Set 8 | kedougou
# Processing Record 43 of Set 8 | luanda
# Processing Record 44 of Set 8 | maxixe
# Processing Record 45 of Set 8 | rochegda
# Processing Record 46 of Set 8 | watsa
# Processing Record 47 of Set 8 | crotone
# Processing Record 48 of Set 8 | makat
# Processing Record 49 of Set 8 | burica
# City not found. Skipping...
# Processing Record 50 of Set 8 | kawambwa
# Processing Record 1 of Set 9 | farah
# Processing Record 2 of Set 9 | marietta
# Processing Record 3 of Set 9 | madarounfa
# Processing Record 4 of Set 9 | sinnamary
# Processing Record 5 of Set 9 | nassau
# Processing Record 6 of Set 9 | sturgeon falls
# Processing Record 7 of Set 9 | nylstroom
# City not found. Skipping...
# Processing Record 8 of Set 9 | qostanay
# Processing Record 9 of Set 9 | belmonte
# Processing Record 10 of Set 9 | susangerd
# Processing Record 11 of Set 9 | zomin
# Processing Record 12 of Set 9 | ornes
# Processing Record 13 of Set 9 | sur
# Processing Record 14 of Set 9 | hauterive
# Processing Record 15 of Set 9 | abu dhabi
# Processing Record 16 of Set 9 | wajir
# Processing Record 17 of Set 9 | tchibanga
# Processing Record 18 of Set 9 | balashikha
# Processing Record 19 of Set 9 | nuuk
# Processing Record 20 of Set 9 | magocs
# Processing Record 21 of Set 9 | rudnichnyy
# Processing Record 22 of Set 9 | starosubkhangulovo
# Processing Record 23 of Set 9 | nizwa
# Processing Record 24 of Set 9 | iquique
# Processing Record 25 of Set 9 | betanzos
# Processing Record 26 of Set 9 | iquitos
# Processing Record 27 of Set 9 | kotido
# Processing Record 28 of Set 9 | cuamba
# Processing Record 29 of Set 9 | sokoni
# Processing Record 30 of Set 9 | malanje
# Processing Record 31 of Set 9 | sisimiut
# Processing Record 32 of Set 9 | rocha
# Processing Record 33 of Set 9 | pedernales
# Processing Record 34 of Set 9 | vardo
# Processing Record 35 of Set 9 | brigantine
# Processing Record 36 of Set 9 | la roche-sur-yon
# Processing Record 37 of Set 9 | lalganj
# Processing Record 38 of Set 9 | tucurui
# Processing Record 39 of Set 9 | banes
# Processing Record 40 of Set 9 | cumaribo
# City not found. Skipping...
# Processing Record 41 of Set 9 | itzincab
# City not found. Skipping...
# Processing Record 42 of Set 9 | lindi
# Processing Record 43 of Set 9 | redondo
# Processing Record 44 of Set 9 | schwedt
# Processing Record 45 of Set 9 | trairi
# Processing Record 46 of Set 9 | marawi
# Processing Record 47 of Set 9 | gornopravdinsk
# Processing Record 48 of Set 9 | upata
# Processing Record 49 of Set 9 | laurel
# Processing Record 50 of Set 9 | dhidhdhoo
# Processing Record 1 of Set 10 | dianopolis
# City not found. Skipping...
# Processing Record 2 of Set 10 | el ejido
# Processing Record 3 of Set 10 | shieli
# Processing Record 4 of Set 10 | waddan
# Processing Record 5 of Set 10 | alberton
# Processing Record 6 of Set 10 | arlit
# Processing Record 7 of Set 10 | mosalsk
# Processing Record 8 of Set 10 | inta
# Processing Record 9 of Set 10 | totskoye
# Processing Record 10 of Set 10 | shahdadpur
# Processing Record 11 of Set 10 | vryburg
# Processing Record 12 of Set 10 | arroyo
# Processing Record 13 of Set 10 | shelburne
# Processing Record 14 of Set 10 | svetlyy
# Processing Record 15 of Set 10 | bonthe
# Processing Record 16 of Set 10 | arica
# Processing Record 17 of Set 10 | geraldton
# Processing Record 18 of Set 10 | tombouctou
# Processing Record 19 of Set 10 | san matias
# Processing Record 20 of Set 10 | opuwo
# Processing Record 21 of Set 10 | havre-saint-pierre
# Processing Record 22 of Set 10 | santiago de cao
# Processing Record 23 of Set 10 | halifax
# Processing Record 24 of Set 10 | sinjar
# Processing Record 25 of Set 10 | marsa matruh
# Processing Record 26 of Set 10 | coihueco
# Processing Record 27 of Set 10 | eskasem
# City not found. Skipping...
# Processing Record 28 of Set 10 | chipiona
# Processing Record 29 of Set 10 | pamyat parizhskoy kommuny
# Processing Record 30 of Set 10 | santarem
# Processing Record 31 of Set 10 | saint-junien
# Processing Record 32 of Set 10 | sydney
# Processing Record 33 of Set 10 | palmas de monte alto
# Processing Record 34 of Set 10 | urosevac
# City not found. Skipping...
# Processing Record 35 of Set 10 | warmbad
# Processing Record 36 of Set 10 | morki
# Processing Record 37 of Set 10 | phuntsholing
# Processing Record 38 of Set 10 | nacala
# Processing Record 39 of Set 10 | mahibadhoo
# Processing Record 40 of Set 10 | astaneh-ye ashrafiyeh
# Processing Record 41 of Set 10 | skiros
# City not found. Skipping...
# Processing Record 42 of Set 10 | kanakapura
# Processing Record 43 of Set 10 | grand gaube
# Processing Record 44 of Set 10 | bathsheba
# Processing Record 45 of Set 10 | nicolas bravo
# Processing Record 46 of Set 10 | bolshoye selo
# Processing Record 47 of Set 10 | oranjestad
# Processing Record 48 of Set 10 | boa vista
# Processing Record 49 of Set 10 | brezno
# Processing Record 50 of Set 10 | karonga
# Processing Record 1 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 2 of Set 11 | visnes
# Processing Record 3 of Set 11 | boueni
# Processing Record 4 of Set 11 | mbuji-mayi
# Processing Record 5 of Set 11 | djambala
# Processing Record 6 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 7 of Set 11 | manono
# Processing Record 8 of Set 11 | luba
# Processing Record 9 of Set 11 | kudahuvadhoo
# Processing Record 10 of Set 11 | ust-ishim
# Processing Record 11 of Set 11 | coquimbo
# Processing Record 12 of Set 11 | charagua
# Processing Record 13 of Set 11 | chala
# Processing Record 14 of Set 11 | baneh
# Processing Record 15 of Set 11 | gibara
# Processing Record 16 of Set 11 | maykor
# Processing Record 17 of Set 11 | florida
# Processing Record 18 of Set 11 | sompeta
# Processing Record 19 of Set 11 | buqayq
# City not found. Skipping...
# Processing Record 20 of Set 11 | itacoatiara
# Processing Record 21 of Set 11 | maarianhamina
# Processing Record 22 of Set 11 | panjwin
# City not found. Skipping...
# Processing Record 23 of Set 11 | shalakusha
# Processing Record 24 of Set 11 | kislyakovskaya
# Processing Record 25 of Set 11 | nesbyen
# Processing Record 26 of Set 11 | wyszkow
# Processing Record 27 of Set 11 | muros
# Processing Record 28 of Set 11 | gravdal
# Processing Record 29 of Set 11 | itororo
# Processing Record 30 of Set 11 | caluquembe
# Processing Record 31 of Set 11 | sakakah
# Processing Record 32 of Set 11 | mangan
# Processing Record 33 of Set 11 | cayenne
# Processing Record 34 of Set 11 | reitz
# Processing Record 35 of Set 11 | rusape
# Processing Record 36 of Set 11 | bardiyah
# Processing Record 37 of Set 11 | gazanjyk
# Processing Record 38 of Set 11 | mantua
# Processing Record 39 of Set 11 | bonfim
# Processing Record 40 of Set 11 | vredendal
# Processing Record 41 of Set 11 | bainbridge
# Processing Record 42 of Set 11 | thompson
# Processing Record 43 of Set 11 | rokytne
# Processing Record 44 of Set 11 | umm lajj
# Processing Record 45 of Set 11 | safaga
# Processing Record 46 of Set 11 | chicama
# Processing Record 47 of Set 11 | cap malheureux
# Processing Record 48 of Set 11 | arshan
# Processing Record 49 of Set 11 | okhansk
# Processing Record 50 of Set 11 | andenes
# Processing Record 1 of Set 12 | verkh-chebula
# Processing Record 2 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 3 of Set 12 | rognan
# Processing Record 4 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 5 of Set 12 | chilca
# Processing Record 6 of Set 12 | anori
# Processing Record 7 of Set 12 | la romana
# Processing Record 8 of Set 12 | tres arroyos
# Processing Record 9 of Set 12 | bahia honda
# Processing Record 10 of Set 12 | floro
# Processing Record 11 of Set 12 | safut
# Processing Record 12 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 13 of Set 12 | plasnica
# Processing Record 14 of Set 12 | akom
# Processing Record 15 of Set 12 | paita
# Processing Record 16 of Set 12 | minna
# Processing Record 17 of Set 12 | lumeje
# Processing Record 18 of Set 12 | lawrenceburg
# Processing Record 19 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 20 of Set 12 | teya
# Processing Record 21 of Set 12 | valdemarpils
# Processing Record 22 of Set 12 | makali
# Processing Record 23 of Set 12 | rairangpur
# Processing Record 24 of Set 12 | bafata
# Processing Record 25 of Set 12 | riyadh
# Processing Record 26 of Set 12 | ndago
# Processing Record 27 of Set 12 | margate
# Processing Record 28 of Set 12 | kuliyapitiya
# Processing Record 29 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 30 of Set 12 | yarada
# Processing Record 31 of Set 12 | yirol
# City not found. Skipping...
# Processing Record 32 of Set 12 | maputo
# Processing Record 33 of Set 12 | rudbar
# Processing Record 34 of Set 12 | henties bay
# Processing Record 35 of Set 12 | furmanov
# Processing Record 36 of Set 12 | kyrylivka
# Processing Record 37 of Set 12 | terra santa
# Processing Record 38 of Set 12 | vysotskoye
# Processing Record 39 of Set 12 | caranavi
# Processing Record 40 of Set 12 | kwekwe
# Processing Record 41 of Set 12 | san carlos de bariloche
# Processing Record 42 of Set 12 | sioux lookout
# Processing Record 43 of Set 12 | mitsamiouli
# Processing Record 44 of Set 12 | kabare
# Processing Record 45 of Set 12 | farafangana
# Processing Record 46 of Set 12 | almaty
# Processing Record 47 of Set 12 | bantry
# Processing Record 48 of Set 12 | lerwick
# Processing Record 49 of Set 12 | hobyo
# Processing Record 50 of Set 12 | ilhabela
# Processing Record 1 of Set 13 | anzio
# Processing Record 2 of Set 13 | puerto ayacucho
# Processing Record 3 of Set 13 | agapovka
# Processing Record 4 of Set 13 | bubaque
# Processing Record 5 of Set 13 | mikhaylovka
# Processing Record 6 of Set 13 | ariquemes
# Processing Record 7 of Set 13 | reus
# Processing Record 8 of Set 13 | aguas formosas
# Processing Record 9 of Set 13 | kolvereid
# Processing Record 10 of Set 13 | la palma
# Processing Record 11 of Set 13 | maloshuyka
# City not found. Skipping...
# Processing Record 12 of Set 13 | repatriacion
# Processing Record 13 of Set 13 | neyshabur
# Processing Record 14 of Set 13 | mvomero
# Processing Record 15 of Set 13 | port said
# Processing Record 16 of Set 13 | coruripe
# Processing Record 17 of Set 13 | pangody
# Processing Record 18 of Set 13 | keetmanshoop
# Processing Record 19 of Set 13 | corrientes
# Processing Record 20 of Set 13 | shache
# Processing Record 21 of Set 13 | vila velha
# Processing Record 22 of Set 13 | guiratinga
# Processing Record 23 of Set 13 | amudat
# Processing Record 24 of Set 13 | alausi
# Processing Record 25 of Set 13 | ochamchira
# Processing Record 26 of Set 13 | vizinga
# Processing Record 27 of Set 13 | teguldet
# Processing Record 28 of Set 13 | murgab
# Processing Record 29 of Set 13 | nantucket
# Processing Record 30 of Set 13 | solotvyn
# Processing Record 31 of Set 13 | abong mbang
# Processing Record 32 of Set 13 | male
# Processing Record 33 of Set 13 | idukki
# Processing Record 34 of Set 13 | mbini
# Processing Record 35 of Set 13 | poptun
# Processing Record 36 of Set 13 | eenhana
# Processing Record 37 of Set 13 | suez
# Processing Record 38 of Set 13 | campoverde
# Processing Record 39 of Set 13 | khandbari
# Processing Record 40 of Set 13 | amboasary
# Processing Record 41 of Set 13 | bria
# Processing Record 42 of Set 13 | kidal
# Processing Record 43 of Set 13 | galle
# Processing Record 44 of Set 13 | thinadhoo
# Processing Record 45 of Set 13 | villa rica
# Processing Record 46 of Set 13 | colares
# Processing Record 47 of Set 13 | darnah
# Processing Record 48 of Set 13 | batatais
# Processing Record 49 of Set 13 | corinto
# Processing Record 50 of Set 13 | gundorovskiy
# Processing Record 1 of Set 14 | arcabuco
# Processing Record 2 of Set 14 | vuktyl
# Processing Record 3 of Set 14 | barreirinhas
# Processing Record 4 of Set 14 | kuytun
# Processing Record 5 of Set 14 | san juan de los morros
# Processing Record 6 of Set 14 | huarmey
# Processing Record 7 of Set 14 | iracoubo
# Processing Record 8 of Set 14 | hillsborough
# Processing Record 9 of Set 14 | abu jubayhah
# City not found. Skipping...
# Processing Record 10 of Set 14 | belyy yar
# Processing Record 11 of Set 14 | rondonopolis
# Processing Record 12 of Set 14 | iskateley
# Processing Record 13 of Set 14 | dangriga
# Processing Record 14 of Set 14 | tahta
# Processing Record 15 of Set 14 | othonoi
# City not found. Skipping...
# Processing Record 16 of Set 14 | kinanah
# City not found. Skipping...
# Processing Record 17 of Set 14 | pimenta bueno
# Processing Record 18 of Set 14 | sao joaquim
# Processing Record 19 of Set 14 | talcahuano
# Processing Record 20 of Set 14 | tabou
# Processing Record 21 of Set 14 | kurchum
# Processing Record 22 of Set 14 | kaspiysk
# Processing Record 23 of Set 14 | elat
# Processing Record 24 of Set 14 | sept-iles
# Processing Record 25 of Set 14 | krasnoarmeysk
# Processing Record 26 of Set 14 | ostersund
# Processing Record 27 of Set 14 | buenos aires
# Processing Record 28 of Set 14 | thunder bay
# Processing Record 29 of Set 14 | gilazi
# City not found. Skipping...
# Processing Record 30 of Set 14 | kulhudhuffushi
# Processing Record 31 of Set 14 | chimbarongo
# Processing Record 32 of Set 14 | ambilobe
# Processing Record 33 of Set 14 | buarcos
# Processing Record 34 of Set 14 | menongue
# Processing Record 35 of Set 14 | pelym
# Processing Record 36 of Set 14 | bichena
# Processing Record 37 of Set 14 | kargasok
# Processing Record 38 of Set 14 | ciudad guayana
# Processing Record 39 of Set 14 | ondjiva
# Processing Record 40 of Set 14 | amapa
# Processing Record 41 of Set 14 | junagarh
# Processing Record 42 of Set 14 | marsh harbour
# Processing Record 43 of Set 14 | liverpool
# Processing Record 44 of Set 14 | qunduz
# Processing Record 45 of Set 14 | georgiyevskoye
# Processing Record 46 of Set 14 | santa vitoria do palmar
# Processing Record 47 of Set 14 | yevsino
# Processing Record 48 of Set 14 | kangaatsiaq
# Processing Record 49 of Set 14 | koson
# Processing Record 50 of Set 14 | okakarara
# Processing Record 1 of Set 15 | murygino
# Processing Record 2 of Set 15 | voznesenye
# Processing Record 3 of Set 15 | ilula
# Processing Record 4 of Set 15 | altay
# Processing Record 5 of Set 15 | akureyri
# Processing Record 6 of Set 15 | brae
# Processing Record 7 of Set 15 | puerto gaitan
# Processing Record 8 of Set 15 | vagur
# Processing Record 9 of Set 15 | shubarkuduk
# Processing Record 10 of Set 15 | pontal do parana
# Processing Record 11 of Set 15 | mindelo
# Processing Record 12 of Set 15 | vestmanna
# Processing Record 13 of Set 15 | adjumani
# Processing Record 14 of Set 15 | puerto baquerizo moreno
# Processing Record 15 of Set 15 | yamandu
# Processing Record 16 of Set 15 | tokzar
# City not found. Skipping...
# Processing Record 17 of Set 15 | salinopolis
# Processing Record 18 of Set 15 | yantzaza
# Processing Record 19 of Set 15 | mahajanga
# Processing Record 20 of Set 15 | viedma
# Processing Record 21 of Set 15 | monte patria
# Processing Record 22 of Set 15 | bocaranga
# City not found. Skipping...
# Processing Record 23 of Set 15 | sadovo
# Processing Record 24 of Set 15 | stolin
# Processing Record 25 of Set 15 | dori
# Processing Record 26 of Set 15 | alexandria
# Processing Record 27 of Set 15 | abha
# Processing Record 28 of Set 15 | storslett
# Processing Record 29 of Set 15 | karpathos
# Processing Record 30 of Set 15 | lokosovo
# Processing Record 31 of Set 15 | siilinjarvi
# Processing Record 32 of Set 15 | ankazoabo
# Processing Record 33 of Set 15 | the valley
# Processing Record 34 of Set 15 | castro-urdiales
# Processing Record 35 of Set 15 | korla
# Processing Record 36 of Set 15 | petrolandia
# City not found. Skipping...
# Processing Record 37 of Set 15 | kosino
# Processing Record 38 of Set 15 | teguise
# Processing Record 39 of Set 15 | arkhangelos
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 676

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             Matagalpa  12.9256  -85.9175     79.61        68          40
# 1             Hithadhoo  -0.6000   73.0833     79.77        74          66
# 2         Ponta Delgada  37.7333  -25.6667     57.92        82          20
# 3              Manavgat  36.7867   31.4431     53.91        59           0
# 4  Vila Franca Do Campo  37.7167  -25.4333     57.61        77          99
# 5          Saint George  37.1041 -113.5841     44.44        80         100
# 6                  Faya  18.3851   42.4509     43.32        67          15
# 7        Saint-Philippe -21.3585   55.7679     74.79        79          39
# 8       Arraial Do Cabo -22.9661  -42.0278     74.14        90         100
# 9          Punta Arenas -53.1500  -70.9167     53.71        50          40
#
#    Wind Speed Country Current Description
# 0        0.00      NI    scattered clouds
# 1        4.97      MV       broken clouds
# 2       26.46      PT          light rain
# 3        4.34      TR           clear sky
# 4       24.16      PT     overcast clouds
# 5        1.01      US     overcast clouds
# 6        3.51      SA          few clouds
# 7        5.10      RE    scattered clouds
# 8       20.83      BR          light rain
# 9       29.93      CL    scattered clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[order]

# Display sample data
city_data_df.head()
# Out:
#                    City Country      Lat      Lng  Max Temp  Humidity  \
# 0             Matagalpa      NI  12.9256 -85.9175     79.61        68
# 1             Hithadhoo      MV  -0.6000  73.0833     79.77        74
# 2         Ponta Delgada      PT  37.7333 -25.6667     57.92        82
# 3              Manavgat      TR  36.7867  31.4431     53.91        59
# 4  Vila Franca Do Campo      PT  37.7167 -25.4333     57.61        77
#
#    Cloudiness  Wind Speed Current Description
# 0          40        0.00    scattered clouds
# 1          66        4.97       broken clouds
# 2          20       26.46          light rain
# 3           0        4.34           clear sky
# 4          99       24.16     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file,index_label="City_ID")
